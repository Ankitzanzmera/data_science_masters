# %% [markdown]
# #### Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of Matplotlib.

# %% [markdown]
# Matplot is comprehensive library for creating static, animated and interactive visualizations in python.

# %% [markdown]
# 1) Create publication quality plots.
# 2) Make interactive figures that can zoom, pan, update.
# 3) Customize visual style and layout.
# 4) Export to many file formats.
# 5) Embed in JupyterLab and Graphical User Interfaces.
# 6) Use a rich array of third-party packages built on Matplotlib.

# %% [markdown]
# #### Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data plot a scatter plot.

# %% [markdown]
# #### import numpy as np
# #### np.random.seed(3)
# #### x = 3 + np.random.normal(0, 2, 50)
# #### y = 3 + np.random.normal(0, 2, len(x))
# #### Note: Also add title, xlabel, and ylabel to the plot.

# %% [markdown]
# A scatter plot is diagram where each data is represented by dot.

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
np.random.seed(3)
x = 3 + np.random.normal(0,2,50)
y = 3 + np.random.normal(0,2,len(x))

# %%
plt.scatter(x,y)
plt.xlabel('This is x')
plt.xlabel('This is y')
plt.title('This is x and y')
# Out:
# Text(0.5, 1.0, 'This is x and y')

# %% [markdown]
# #### Q3: Why is the subplot() function used? Draw four line plots using the subplot() function. Use the following data:

# %% [markdown]
# import numpy as np
# For line 1: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([0, 100, 200, 300, 400, 500])
# For line 2: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([50, 20, 40, 20, 60, 70])
# For line 3: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([10, 20, 30, 40, 50, 60])
# For line 4: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([200, 350, 250, 550, 450, 150])

# %% [markdown]
# subplot() takes three arguement first two describes layout wher third is for index of current plot.

# %%
import numpy as np

# %%
# plot 1
x = np.array([0,1,2,3,4,5])
y = np.array([0,100,200,300,400,500])
plt.subplot(2,2,1)
plt.plot(x,y)

# plot 2
x = np.array([0,1,2,3,4,5])
y = np.array([50,20,40,20,60,70])
plt.subplot(2,2,2)
plt.plot(x,y)

# plot 3
x = np.array([0,1,2,3,4,5])
y = np.array([10,20,30,40,50,60])
plt.subplot(2,2,3)
plt.plot(x,y)

# plot 3
x = np.array([0,1,2,3,4,5])
y = np.array([200,350,250,550,450,150])
plt.subplot(2,2,4)
plt.plot(x,y)

# %% [markdown]
# #### Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.

# %% [markdown]
# company = np.array(["Apple", "Microsoft", "Google", "AMD"])
# profit = np.array([3000, 8000, 1000, 10000])

# %% [markdown]
# Bar plot is type of data visualization used to represent the data in rectangular form. its easy to understand and also used to when we are showing segment between two groups.

# %%
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])
plt.bar(company,profit)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# #### Q5: What is a box plot? Why is it used? Using the following data plot a box plot.

# %%
box1 = np.random.normal(100, 10, 200)
plt.boxplot(box1)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x19f9a081d90>,
#   <matplotlib.lines.Line2D at 0x19f9a0910a0>],
#  'caps': [<matplotlib.lines.Line2D at 0x19f9a091370>,
#   <matplotlib.lines.Line2D at 0x19f9a091640>],
#  'boxes': [<matplotlib.lines.Line2D at 0x19f9a081a90>],
#  'medians': [<matplotlib.lines.Line2D at 0x19f9a091910>],
#  'fliers': [<matplotlib.lines.Line2D at 0x19f9a091be0>],
#  'means': []}

# %%
box2 = np.random.normal(90, 20, 200)
plt.boxplot(box2)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x19f99ff6070>,
#   <matplotlib.lines.Line2D at 0x19f99e33340>],
#  'caps': [<matplotlib.lines.Line2D at 0x19f99e61a60>,
#   <matplotlib.lines.Line2D at 0x19f99e801f0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x19f99ff6190>],
#  'medians': [<matplotlib.lines.Line2D at 0x19f99e80eb0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x19f99e80a90>],
#  'means': []}
